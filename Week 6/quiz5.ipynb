# %% [markdown]
# $$\Huge\text{ Quiz 5} $$

# %% [markdown]
# # Model
# <font size=4> Use a XGBoost to predict the mpg for the auto data set provided. <br><br> <font color=blue>Use the defaults for  xgboost.XGBRegressor() for your  model. <br><br>Test for overfitting by providing a score on a test and train set.( random_state=42 and default split size)<br> <br>Apply a Standard Scaler to the data.</font>  <br>  <br>I used some of these tools to get get the data ready for processing, but you may want to use others.
#
#     df .isna.sum()
#     df.dropna()
#     df.loc[:,df.columns!='mpg']

# %% [markdown]
# <font size =4 color = blue>  __Produce two scatter plots for predictions and actual values.  One for the scaled train set and another for the scaled test set  ?__

# %% [markdown]
# <font size =4 color = blue>  __What feature is most important for your best model?__
#
# <font color=brown> __Answer__

# %% [markdown]
# # Summary
#
# <font size=4 color=blue>
# <br>
#
# * What is the score for the model?  Hint it isn't accuracy.
# * The model is overfitting the train set.  Explain why we know this.
# * The model still appears to be a good model.  Explain.

# %% [markdown]
# <font color=brown size=4> __Answers__
