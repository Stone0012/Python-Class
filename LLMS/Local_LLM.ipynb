# %%
#pip install ollama

# %%
import requests
import ollama


SERVER_URL = "http://lambda2.uncw.edu:11434/api/generate"
payload = {
    "model": 'gemma',
    "prompt": f"Write a poem about dogs",
    "stream": False
}



response = requests.post(SERVER_URL, json=payload)
response_json = response.json()  # Convert response to dictionary
print(response_json.get("response", "Key 'response' not found"))
# Out:
# Soft paws on polished floor,
# Tail a beacon, beating store.
# Eyes like pools reflecting gold,
# A furry friend, a story untold.
#
# From playful pups to gentle giants,
# Loyal hearts in countless sizes.
# Each bark a song, a joyous call,
# Their love unconditional, standing tall.
#
# They chase the ball, they fetch the stick,
# Their boundless energy, a playful click.
# Through fields they bound, a joyous blur,
# Their love for life, a constant stir.
#
# In quiet moments, snuggled near,
# A gentle warmth, banishing fear.
# Their silent presence brings a smile,
# A love that fills each passing mile.
#
# They guard our homes with watchful eyes,
# Protecting loved ones under open skies.
# Their loyalty knows no bounds,
# A bond that time forever rounds.
#
# So here's to dogs, our furry friends,
# Your love unwavering till the very end.
# Your gentle souls, your playful might,
# A precious gift, shining bright.
