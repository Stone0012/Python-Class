# %% [markdown]
# $$\Huge{\text{ Quiz 3}}$$
#
# <font size=6> __Name:__

# %% [markdown]
#
# <font size=4>Remember to print the file to pdf and name it:  __Lastname_Firstname_Quiz3.pdf__
#
# <font color=red>
#
#
#  CHECK THE FILE before you submit it to the folder in Teams

# %% [markdown]
# # Linear regression with Categorical data.
#
# <font size=4>  The data set contains information on 1460 ( original was bigger but we dropped NANS) properties in Ames, Iowa, including columns related to:
#
#     house characteristics (bedrooms, garage, fireplace, pool, porch, etc.)
#     location (neighborhood)
#     lot information (zoning, shape, size, etc.)
#     ratings of condition and quality
#     sale price( we will use this as the target and the rest as the features)
# https://inria.github.io/scikit-learn-mooc/python_scripts/datasets_ames_housing.html

# %% [markdown]
# ## Predict sale price

# %%
import pandas as pd
import numpy as np
ames= pd.read_csv("https://raw.githubusercontent.com/INRIA/scikit-learn-mooc/main/datasets/ames_housing_no_missing.csv", na_values='?')
ames =ames.sample(frac = 1, random_state=73) #I shuffled the data here
#ames

# %% [markdown]
# <font size=4 color =blue> Here we will set the target and the features. Notice some are numeric and some are text or object.Take of # below for more details

# %%
target_name = "SalePrice"
data, target = ames.drop(columns=target_name), ames[target_name]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1450 to 918
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## One-hot

# %% [markdown]
# <font size =4 color =red> Divide the data up into numeric and string.

# %%
df_num=(ames[["Fare"]])
df_cat=(ames[['Sex', "Pclass","Embarked"]])
df_surv=ames["SalePrice"]

# %% [markdown]
# <font size=4 color =red> One hot encode the string_data.

# %% [markdown]
# <font size=4 color =red>   What are the shapes of the the string_data vs the encoded string_data. Does this make sense?

# %% [markdown]
# <font size=4 color=brown> __Answer:__

# %% [markdown]
# <font size=4 color=red> Join the numerical and categorical data.

# %% [markdown]
# <font size=4 color =red> Let's train_test_split the data using default test_size and random_state=37.

# %% [markdown]
# <font size =4 color =red>  Use ScikitLearn's LinearRegression() to run a model on the concatenated data.  __Score it on the train set and perform a 4 fold cross validation.__

# %% [markdown]
# <font size=4 color=red> __Score it on the test set.__

# %% [markdown]
# <font size =4 color = red>__Plot the predictions and actual values as an ordered pair similarly as we did for the auto  data set in Module 3.__
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <font size="3">

# %% [markdown]
# <FONT size=4 color =red> What are your thought about this model?  Ideas on how to improve it.

# %% [markdown]
# <font size=4 color=brown> __Answer:__
